# %% [markdown]
# ### 第9章 绘图与可视化

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = np.arange(10)
plt.plot(data)

# %%
fig = plt.figure(figsize=(10, 6))

ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

ax1.hist(np.random.randn(100), bins=20, color="k", alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# plt.plot([1.5, 3.5, -2, 1.6])
plt.plot(np.random.randn(50).cumsum(), "k--")

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color="k", alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)

# %%
plt.figure(figsize=(10, 6))
plt.plot(np.random.randn(30).cumsum(), "ko--")

# %%
data = np.random.randn(30).cumsum()

# %%
plt.plot(data, "k--", label="Default")

# %%
plt.plot(data, "k-", drawstyle="steps-post", label="steps-post")

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0), columns=list("ABCD"), index=np.arange(0, 100, 10))
df.plot()

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.rand(16), index=list("abcdefghijklmnop"))
data.plot.bar(ax=axes[0], color="k", alpha=0.7)
data.plot.barh(ax=axes[1], color="k", alpha=0.7)

# %%
df = pd.DataFrame(
    np.random.rand(6, 4),
    index=["one", "two", "three", "four", "five", "six"],
    columns=pd.Index(list("ABCD"), name="Genus")
)
df
# Out:
# Genus         A         B         C         D
# one    0.739824  0.515670  0.923982  0.620791
# two    0.307989  0.838967  0.081752  0.021356
# three  0.014651  0.957141  0.930720  0.469464
# four   0.177309  0.375524  0.249996  0.874095
# five   0.457315  0.776173  0.810813  0.089396
# six    0.319780  0.567830  0.248224  0.840732

# %%
df.plot.bar()

# %%
df.plot.barh(stacked=True, alpha=0.5)
